# %%
# Exploring census data
# By Adriana Valencia Wences

# %%
# import libraries
# for general data wrangling tasks
import pandas as pd

# to read and visualize spatial data
import geopandas as gpd

# to provide basemaps 
import contextily as ctx

# to give more power to your figures (plots)
import matplotlib.pyplot as plt

# %%
# load a data file
income = gpd.read_file('data/LongBeach_2019_income.geojson')

# %%
# inspect data
income.shape
# Out:
# (27, 37)

# %%
income.head()
# Out:
#             geoid            name  B19001001  B19001001, Error  B19001002  \
# 0  16000US0643000  Long Beach, CA   166813.0            1057.0     9472.0
# 1    86000US90221           90221    12144.0             220.0      620.0
# 2    86000US90630           90630    15804.0             263.0      444.0
# 3    86000US90706           90706    23240.0             497.0      874.0
# 4    86000US90712           90712    10338.0             215.0      311.0
#
#    B19001002, Error  B19001003  B19001003, Error  B19001004  B19001004, Error  \
# 0             654.0     7907.0             539.0     6313.0             578.0
# 1             123.0      682.0             155.0      605.0             132.0
# 2             107.0      246.0              82.0      345.0             109.0
# 3             159.0     1398.0             249.0     1047.0             219.0
# 4              79.0      212.0             110.0      178.0              88.0
#
# ...

# %%
# plot it!
income.plot(figsize=(10,10))
# Out:
# <AxesSubplot:>

# %%
# delete summary row
# drop the row with index 0 (i.e. the first row)
income = income.drop([0])

# %%
# check to see if it has been deleted
income.head()
# Out:
#           geoid   name  B19001001  B19001001, Error  B19001002  \
# 1  86000US90221  90221    12144.0             220.0      620.0
# 2  86000US90630  90630    15804.0             263.0      444.0
# 3  86000US90706  90706    23240.0             497.0      874.0
# 4  86000US90712  90712    10338.0             215.0      311.0
# 5  86000US90713  90713     9111.0             182.0      289.0
#
#    B19001002, Error  B19001003  B19001003, Error  B19001004  B19001004, Error  \
# 1             123.0      682.0             155.0      605.0             132.0
# 2             107.0      246.0              82.0      345.0             109.0
# 3             159.0     1398.0             249.0     1047.0             219.0
# 4              79.0      212.0             110.0      178.0              88.0
# 5              94.0       98.0              60.0      254.0              93.0
#
#    ...  B19001013, Error  B19001014  B19001014, Error  B19001015  \
# ...

# %%
# I want to see all the data
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %%
income.sample()
# Out:
#            geoid   name  B19001001  B19001001, Error  B19001002  \
# 17  86000US90805  90805    27354.0             378.0     1688.0
#
#     B19001002, Error  B19001003  B19001003, Error  B19001004  \
# 17             266.0     1451.0             237.0     1207.0
#
#     B19001004, Error  B19001005  B19001005, Error  B19001006  \
# 17             241.0     1748.0             289.0     1442.0
#
#     B19001006, Error  B19001007  B19001007, Error  B19001008  \
# 17             317.0     1619.0             249.0     1564.0
#
#     B19001008, Error  B19001009  B19001009, Error  B19001010  \
# 17             246.0     1482.0             287.0     1190.0
#
#     B19001010, Error  B19001011  B19001011, Error  B19001012  \
# 17             241.0     2295.0             348.0     2629.0
#
#     B19001012, Error  B19001013  B19001013, Error  B19001014  \
# 17             330.0     3654.0             414.0     2509.0
#
#     B19001014, Error  B19001015  B19001015, Error  B19001016  \
# ...

# %%
# look at the data types
income.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# Int64Index: 26 entries, 1 to 26
# Data columns (total 37 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   geoid             26 non-null     object
#  1   name              26 non-null     object
#  2   B19001001         26 non-null     float64
#  3   B19001001, Error  26 non-null     float64
#  4   B19001002         26 non-null     float64
#  5   B19001002, Error  26 non-null     float64
#  6   B19001003         26 non-null     float64
#  7   B19001003, Error  26 non-null     float64
#  8   B19001004         26 non-null     float64
#  9   B19001004, Error  26 non-null     float64
#  10  B19001005         26 non-null     float64
#  11  B19001005, Error  26 non-null     float64
#  12  B19001006         26 non-null     float64
#  13  B19001006, Error  26 non-null     float64
#  14  B19001007         26 non-null     float64
#  15  B19001007, Error  26 non-null     float64
# ...

# %%
# look at fips codes
income.geoid.head()
# Out:
# 1    86000US90221
# 2    86000US90630
# 3    86000US90706
# 4    86000US90712
# 5    86000US90713
# Name: geoid, dtype: object

# %%
# need to drop some columns
list(income)
# Out:
# ['geoid',
#  'name',
#  'B19001001',
#  'B19001001, Error',
#  'B19001002',
#  'B19001002, Error',
#  'B19001003',
#  'B19001003, Error',
#  'B19001004',
#  'B19001004, Error',
#  'B19001005',
#  'B19001005, Error',
#  'B19001006',
#  'B19001006, Error',
#  'B19001007',
#  'B19001007, Error',
#  'B19001008',
#  'B19001008, Error',
#  'B19001009',
#  'B19001009, Error',
#  'B19001010',
#  'B19001010, Error',
#  'B19001011',
#  'B19001011, Error',
#  'B19001012',
#  'B19001012, Error',
#  'B19001013',
#  'B19001013, Error',
#  'B19001014',
#  'B19001014, Error',
#  'B19001015',
#  'B19001015, Error',
#  'B19001016',
#  'B19001016, Error',
#  'B19001017',
#  'B19001017, Error',
#  'geometry']

# %%
# columns to keep
columns_to_keep = ['geoid',
 'name',
 'B19001001',
 'B19001002',
 'B19001003',
 'B19001004',
 'B19001005',
 'B19001006',
 'B19001007',
 'B19001008',
 'B19001009',
 'B19001010',
 'B19001011',
 'B19001012',
 'B19001013',
 'B19001014',
 'B19001015',
 'B19001016',
 'B19001017',
 'geometry']

# %%
# redefine income with only columns to keep
income = income[columns_to_keep]

# %%
# check the slimmed down gdf
income.head()
# Out:
#           geoid   name  B19001001  B19001002  B19001003  B19001004  B19001005  \
# 1  86000US90221  90221    12144.0      620.0      682.0      605.0      736.0
# 2  86000US90630  90630    15804.0      444.0      246.0      345.0      370.0
# 3  86000US90706  90706    23240.0      874.0     1398.0     1047.0     1104.0
# 4  86000US90712  90712    10338.0      311.0      212.0      178.0      111.0
# 5  86000US90713  90713     9111.0      289.0       98.0      254.0      291.0
#
#    B19001006  B19001007  B19001008  B19001009  B19001010  B19001011  \
# 1      586.0      838.0      486.0      667.0      592.0     1297.0
# 2      271.0      392.0      538.0      417.0      410.0      803.0
# 3     1053.0     1158.0     1272.0     1042.0      754.0     1916.0
# 4      214.0      321.0      346.0      221.0      305.0      412.0
# 5      181.0      199.0      165.0      262.0      230.0      541.0
#
#    B19001012  B19001013  B19001014  B19001015  B19001016  B19001017  \
# ...

# %%
# rename columns
list(income)
# Out:
# ['geoid',
#  'name',
#  'B19001001',
#  'B19001002',
#  'B19001003',
#  'B19001004',
#  'B19001005',
#  'B19001006',
#  'B19001007',
#  'B19001008',
#  'B19001009',
#  'B19001010',
#  'B19001011',
#  'B19001012',
#  'B19001013',
#  'B19001014',
#  'B19001015',
#  'B19001016',
#  'B19001017',
#  'geometry']

# %%
income.columns = ['geoid', 
'Zip Code', 'Total',
'Less than $10,000',
'$10,000 to $14,999', 
'$15,000 to $19,999', 
'$20,000 to $24,999',
'$25,000 to $29,999',
'$30,000 to $34,999', 
'$35,000 to $39,999',
'$40,000 to $44,999',
'$45,000 to $49,999',
'$50,000 to $59,999',
'$60,000 to $74,999',
'$75,000 to $99,999',
'$100,000 to $124,999',
'$125,000 to $149,999',
'$150,000 to $199,999',
'$200,000 or more',
'geometry']

# %%
income.head()
# Out:
#           geoid Zip Code    Total  Less than $10,000  $10,000 to $14,999  \
# 1  86000US90221    90221  12144.0              620.0               682.0
# 2  86000US90630    90630  15804.0              444.0               246.0
# 3  86000US90706    90706  23240.0              874.0              1398.0
# 4  86000US90712    90712  10338.0              311.0               212.0
# 5  86000US90713    90713   9111.0              289.0                98.0
#
#    $15,000 to $19,999  $20,000 to $24,999  $25,000 to $29,999  \
# 1               605.0               736.0               586.0
# 2               345.0               370.0               271.0
# 3              1047.0              1104.0              1053.0
# 4               178.0               111.0               214.0
# 5               254.0               291.0               181.0
#
#    $30,000 to $34,999  $35,000 to $39,999  $40,000 to $44,999  \
# 1               838.0               486.0               667.0
# ...

# %%
# get a random record
random_zip = income.sample()
random_zip
# Out:
#            geoid Zip Code  Total  Less than $10,000  $10,000 to $14,999  \
# 25  86000US90822    90822    0.0                0.0                 0.0
#
#     $15,000 to $19,999  $20,000 to $24,999  $25,000 to $29,999  \
# 25                 0.0                 0.0                 0.0
#
#     $30,000 to $34,999  $35,000 to $39,999  $40,000 to $44,999  \
# 25                 0.0                 0.0                 0.0
#
#     $45,000 to $49,999  $50,000 to $59,999  $60,000 to $74,999  \
# 25                 0.0                 0.0                 0.0
#
#     $75,000 to $99,999  $100,000 to $124,999  $125,000 to $149,999  \
# 25                 0.0                   0.0                   0.0
#
#     $150,000 to $199,999  $200,000 or more  \
# 25                   0.0               0.0
#
#                                              geometry
# 25  MULTIPOLYGON (((-118.12235 33.77945, -118.1223...

# %%
# "for the 0th record, get the value in the Total column"
random_zip.iloc[0]['Total']
# Out:
# 0.0

# %%
# print this out in plain english
print('Total: ' + str(random_zip.iloc[0]['Total']))
# Out:
# Total: 0.0

# %%
income['Total'].head()
# Out:
# 1    12144.0
# 2    15804.0
# 3    23240.0
# 4    10338.0
# 5     9111.0
# Name: Total, dtype: float64

# %%
zips_sorted = income.sort_values(by='Zip Code',ascending = False)

# %%
# display the data, but just a few columns to keep it clean
zips_sorted.head(30)
# Out:
#            geoid Zip Code    Total  Less than $10,000  $10,000 to $14,999  \
# 26  86000US90831    90831      0.0                0.0                 0.0
# 25  86000US90822    90822      0.0                0.0                 0.0
# 24  86000US90815    90815  14556.0              817.0               241.0
# 23  86000US90814    90814   9165.0              422.0               310.0
# 22  86000US90813    90813  17192.0             1058.0              1673.0
# 21  86000US90810    90810   9400.0              476.0               427.0
# 20  86000US90808    90808  13916.0              594.0               237.0
# 19  86000US90807    90807  12741.0              381.0               365.0
# 18  86000US90806    90806  12788.0              578.0               820.0
# 17  86000US90805    90805  27354.0             1688.0              1451.0
# 16  86000US90804    90804  14955.0             1012.0              1008.0
# 15  86000US90803    90803  16718.0              772.0               272.0
# ...

# %%
# there is no data for 90831 and 90822; 90755 is signal hill. need to drop them
income.drop([13,26,25]).head(30)
# Out:
#            geoid Zip Code    Total  Less than $10,000  $10,000 to $14,999  \
# 1   86000US90221    90221  12144.0              620.0               682.0
# 2   86000US90630    90630  15804.0              444.0               246.0
# 3   86000US90706    90706  23240.0              874.0              1398.0
# 4   86000US90712    90712  10338.0              311.0               212.0
# 5   86000US90713    90713   9111.0              289.0                98.0
# 6   86000US90715    90715   6018.0              242.0               210.0
# 7   86000US90716    90716   3670.0              156.0               286.0
# 8   86000US90720    90720   7843.0              217.0               145.0
# 9   86000US90723    90723  14207.0              731.0               765.0
# 10  86000US90731    90731  22695.0             1572.0              1255.0
# 11  86000US90740    90740  12550.0              454.0               470.0
# 12  86000US90744    90744  14788.0              659.0               766.0
# ...

# %%
income.columns
# Out:
# Index(['geoid', 'Zip Code', 'Total', 'Less than $10,000', '$10,000 to $14,999',
#        '$15,000 to $19,999', '$20,000 to $24,999', '$25,000 to $29,999',
#        '$30,000 to $34,999', '$35,000 to $39,999', '$40,000 to $44,999',
#        '$45,000 to $49,999', '$50,000 to $59,999', '$60,000 to $74,999',
#        '$75,000 to $99,999', '$100,000 to $124,999', '$125,000 to $149,999',
#        '$150,000 to $199,999', '$200,000 or more', 'geometry'],
#       dtype='object')

# %%
income['below_AMI'] = income['Less than $10,000']

# %%
income
# Out:
#            geoid Zip Code    Total  Less than $10,000  $10,000 to $14,999  \
# 1   86000US90221    90221  12144.0              620.0               682.0
# 2   86000US90630    90630  15804.0              444.0               246.0
# 3   86000US90706    90706  23240.0              874.0              1398.0
# 4   86000US90712    90712  10338.0              311.0               212.0
# 5   86000US90713    90713   9111.0              289.0                98.0
# 6   86000US90715    90715   6018.0              242.0               210.0
# 7   86000US90716    90716   3670.0              156.0               286.0
# 8   86000US90720    90720   7843.0              217.0               145.0
# 9   86000US90723    90723  14207.0              731.0               765.0
# 10  86000US90731    90731  22695.0             1572.0              1255.0
# 11  86000US90740    90740  12550.0              454.0               470.0
# 12  86000US90744    90744  14788.0              659.0               766.0
# ...
